# %% [markdown]
# # Subplots

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

plt.style.use(plt.style.available[9]) # Seaborn style

# %%
df = pd.read_csv('./data/data-subplot.csv')
df.head()
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446
# 1   19     16500   17100       16791
# 2   20     18012   20000       18942
# 3   21     20628   24744       21780
# 4   22     25206   30500       25704

# %%
# Get columns
ages = df['Age']
dev_salaries = df['All_Devs']
py_salaries = df['Python']
js_salaries = df['JavaScript']

# %%
# Plot using pandas
pd_chart = df

del pd_chart['Age']
pd_chart.plot.area()

# %%
plt.plot(ages, py_salaries, label="Python")
plt.plot(ages, js_salaries, label="JavaScript")
plt.plot(ages, dev_salaries, color="#444444", linestyle="--", label="All Devs")

plt.legend()

plt.title("Median salary by age")
plt.xlabel("Age")
plt.ylabel("Salaries (USD)")

plt.tight_layout()

plt.show()

# %%
# With subplot in same image

"""Initiane a new intances of plots"""

fig1, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=True)

ax1.plot(
    ages, dev_salaries, color='#444444', 
    linestyle='-.', label='All Devs'
)
ax1.legend()
ax1.set_title('Median Salary (USD) by Age')
ax1.set_ylabel('Median Salary (USD)')

ax2.plot(ages, py_salaries, label='Python')
ax2.plot(ages, js_salaries, label='JavaScript')
ax2.legend()
ax2.set_ylabel('Median Salary (USD)')
ax2.set_xlabel('Ages')

plt.show()

# %%
# With subplot Different images

"""Initiane a new intances of plots individualy"""

fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()

"""Image 1"""
# Axes
ax1.plot(
    ages, dev_salaries, color='#444444', linestyle='-.', label='All Devs'
)
# Legend
ax1.legend()
ax1.set_title('Median Salary (USD) by Age')
ax1.set_xlabel('Ages')
ax1.set_ylabel('Median Salary (USD)')
"""Image 1"""
# Axes
ax2.plot(ages, py_salaries, label='Python')
ax2.plot(ages, js_salaries, label='JavaScript')
# Legend
ax2.legend()
ax2.set_title('Median Salary (USD) by Age')
ax2.set_xlabel('Ages')
ax2.set_ylabel('Median Salary (USD)')

plt.show()
